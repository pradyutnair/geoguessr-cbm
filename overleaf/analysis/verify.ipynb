# %%
import pandas as pd

df = pd.read_csv("../dataset-43k-mapped.csv")

# %%
df.columns
# Out:
# Index(['image_path', 'pano_id', 'country', 'lat', 'lng', 'meta_name', 'note',
#        'footer', 'images', 'concept'],
#       dtype='object')

# %%
df.meta_name.nunique(), df.concept.nunique()
# Out:
# (2126, 257)
